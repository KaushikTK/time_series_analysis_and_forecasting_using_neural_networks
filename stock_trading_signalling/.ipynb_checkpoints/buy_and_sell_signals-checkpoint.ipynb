# %%
import yfinance as yf
import pandas as pd
import pandas_ta as ta
import talib as ta2
import numpy as np
from datetime import datetime as dt
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
stock = 'WIPRO'
start_date = '2000-01-01'
end_date = dt.now().strftime('%Y-%m-%d')

df = yf.download(f"{stock}.NS", period='1d', start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df['SMA_10'] = ta.sma(df['Adj Close'],length=10)
df['SMA_30'] = ta.sma(df['Adj Close'],length=30)
df['SMA_50'] = ta.sma(df['Adj Close'],length=50)
df['SMA_200'] = ta.sma(df['Adj Close'],length=200)

macd = ta.macd(df['Adj Close'], fast=12, slow=26, signal=9)
df['MACD'] = macd['MACD_12_26_9']
df['MACD_signal'] = macd['MACDs_12_26_9']
df['MACD_hist'] = macd['MACDh_12_26_9']

# %%
df['10_cross_30'] = np.where(df['SMA_10'] > df['SMA_30'], 1, 0)

df['MACD_Signal_MACD'] = np.where(df['MACD_signal'] < df['MACD'], 1, 0)

df['MACD_lim'] = np.where(df['MACD']>0, 1, 0)

df['abv_50'] = np.where((df['SMA_30']>df['SMA_50'])&(df['SMA_10']>df['SMA_50']), 1, 0)

df['abv_200'] = np.where((df['SMA_30']>df['SMA_200'])&(df['SMA_10']>df['SMA_200'])&(df['SMA_50']>df['SMA_200']), 1, 0)

# %%
condition_1 = lambda x: ((x['10_cross_30']==1) and (x['MACD_Signal_MACD']==1) and (x['MACD_lim']==0) and (x['abv_50']==1) and (x['abv_200']==0))

condition_2 = lambda x: ((x['10_cross_30']==1) and (x['MACD_Signal_MACD']==0) and (x['MACD_lim']==1) and (x['abv_50']==0) and (x['abv_200']==0))

condition_3 = lambda x: ((x['10_cross_30']==1) and (x['MACD_Signal_MACD']==1) and (x['MACD_lim']==0) and (x['abv_50']==0) and (x['abv_200']==0))

condition_4 = lambda x: ((x['10_cross_30']==1) and (x['MACD_Signal_MACD']==0) and (x['MACD_lim']==0) and (x['abv_50']==0) and (x['abv_200']==1))

condition_5 = lambda x: ((x['10_cross_30']==0) and (x['MACD_Signal_MACD']==1) and (x['MACD_lim']==1) and (x['abv_50']==0) and (x['abv_200']==0))

# %%
TRADES = []
trade_in_progress = False
holding_period = 14
check_trend_change = True

# %%
def check(row):
    global TRADES, trade_in_progress
    
    if(trade_in_progress):
        _data = TRADES[-1]
        # time to sell after n holding days
        if(row['index']==_data['sell_index']):
            _data['sell_price'] = row['Adj Close']
            _data['sell_date'] = str(pd.to_datetime(row['Date']).date())
            _data['returns'] = round((_data['sell_price']-_data['buy_price'])/_data['buy_price']*100, 2)
            TRADES[-1] = _data
            trade_in_progress = False

        elif((row['index']<_data['sell_index']) and check_trend_change):
            close_trade = False

            # sell if any condition is violated before n holding days
            if((_data['strategy'] in [1]) and ((row['10_cross_30']==0) or (row['MACD_Signal_MACD']==0))): close_trade = True
            elif((_data['strategy']==2) and ((row['10_cross_30']==0) or (row['MACD_lim']==0))): close_trade = True
            elif((_data['strategy']==4) and (row['10_cross_30']==0)): close_trade = True
            elif((_data['strategy']==5) and ((row['MACD_Signal_MACD']==0) or (row['MACD_lim']==0))): close_trade = True

            if(close_trade):
                _data['sell_price'] = row['Adj Close']
                _data['sell_date'] = str(pd.to_datetime(row['Date']).date())
                _data['returns'] = round((_data['sell_price']-_data['buy_price'])/_data['buy_price']*100, 2)
                _data['trend_changed'] = True
                _data['sell_index'] = row['index']
                TRADES[-1] = _data
                trade_in_progress = False
                close_trade = False
            
    else:
        strategy = 0
        if(condition_1(row)): strategy = 1
        elif(condition_2(row)): strategy = 2
        elif(condition_3(row)): strategy = 3
        elif(condition_4(row)): strategy = 4
        elif(condition_5(row)): strategy = 5

        if(strategy>0): 
            trade_in_progress = True
            _data = {
                'strategy': strategy,
                'buy_date': str(pd.to_datetime(row['Date']).date()),
                'buy_index': row['index'],
                'sell_date': '',
                'sell_index': row['index'] + holding_period,
                'buy_price': row['Adj Close'],
                'sell_price': '',
                'returns': 0            
            }
            TRADES.append(_data)
            del _data

df.reset_index().reset_index().apply(check, axis=1)

print('done performing backtesting')
# Out:
# done performing backtesting

# %%
TRADES
# Out:
# [{'strategy': 2,
#   'buy_date': '2000-02-25',
#   'buy_index': 39,
#   'sell_date': '2000-03-14',
#   'sell_index': 51,
#   'buy_price': 210.1140899658203,
#   'sell_price': 164.2180633544922,
#   'returns': -21.84,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2000-06-15',
#   'buy_index': 118,
#   'sell_date': '2000-07-05',
#   'sell_index': 132,
#   'buy_price': 79.04823303222656,
#   'sell_price': 97.84234619140625,
#   'returns': 23.78},
#  {'strategy': 5,
#   'buy_date': '2000-08-22',
#   'buy_index': 166,
#   'sell_date': '2000-09-11',
#   'sell_index': 180,
#   'buy_price': 84.69136047363281,
#   'sell_price': 99.76673126220703,
#   'returns': 17.8},
#  {'strategy': 3,
#   'buy_date': '2000-11-10',
#   'buy_index': 224,
#   'sell_date': '2000-11-30',
#   'sell_index': 238,
#   'buy_price': 71.84784698486328,
#   'sell_price': 78.86007690429688,
#   'returns': 9.76},
#  {'strategy': 5,
#   'buy_date': '2001-01-10',
#   'buy_index': 267,
#   'sell_date': '2001-01-16',
#   'sell_index': 271,
#   'buy_price': 83.09432983398438,
#   'sell_price': 76.98466491699219,
#   'returns': -7.35,
#   'trend_changed': True},
#  {'strategy': 1,
#   'buy_date': '2001-01-17',
#   'buy_index': 272,
#   'sell_date': '2001-02-06',
#   'sell_index': 286,
#   'buy_price': 76.534912109375,
#   'sell_price': 87.5335693359375,
#   'returns': 14.37},
#  {'strategy': 3,
#   'buy_date': '2001-04-27',
#   'buy_index': 344,
#   'sell_date': '2001-05-17',
#   'sell_index': 358,
#   'buy_price': 38.13435363769531,
#   'sell_price': 50.96717071533203,
#   'returns': 33.65},
#  {'strategy': 3,
#   'buy_date': '2001-07-30',
#   'buy_index': 410,
#   'sell_date': '2001-08-14',
#   'sell_index': 421,
#   'buy_price': 41.58952713012695,
#   'sell_price': 44.213809967041016,
#   'returns': 6.31,
#   'trend_changed': True},
#  {'strategy': 2,
#   'buy_date': '2001-08-15',
#   'buy_index': 422,
#   'sell_date': '2001-09-04',
#   'sell_index': 436,
#   'buy_price': 44.213809967041016,
#   'sell_price': 45.88939666748047,
#   'returns': 3.79},
#  {'strategy': 3,
#   'buy_date': '2001-10-23',
#   'buy_index': 471,
#   'sell_date': '2001-11-12',
#   'sell_index': 485,
#   'buy_price': 34.489356994628906,
#   'sell_price': 33.35393524169922,
#   'returns': -3.29},
#  {'strategy': 3,
#   'buy_date': '2001-11-13',
#   'buy_index': 486,
#   'sell_date': '2001-12-03',
#   'sell_index': 500,
#   'buy_price': 33.10297775268555,
#   'sell_price': 46.8671989440918,
#   'returns': 41.58},
#  {'strategy': 3,
#   'buy_date': '2002-08-26',
#   'buy_index': 690,
#   'sell_date': '2002-09-13',
#   'sell_index': 704,
#   'buy_price': 38.4835090637207,
#   'sell_price': 40.21075439453125,
#   'returns': 4.49},
#  {'strategy': 3,
#   'buy_date': '2003-06-18',
#   'buy_index': 902,
#   'sell_date': '2003-07-08',
#   'sell_index': 916,
#   'buy_price': 28.320556640625,
#   'sell_price': 28.759754180908203,
#   'returns': 1.55},
#  {'strategy': 4,
#   'buy_date': '2004-07-12',
#   'buy_index': 1180,
#   'sell_date': '2004-07-16',
#   'sell_index': 1184,
#   'buy_price': 46.70082473754883,
#   'sell_price': 49.24848937988281,
#   'returns': 5.46,
#   'trend_changed': True},
#  {'strategy': 4,
#   'buy_date': '2005-02-22',
#   'buy_index': 1339,
#   'sell_date': '2005-03-01',
#   'sell_index': 1344,
#   'buy_price': 64.01461029052734,
#   'sell_price': 63.28402328491211,
#   'returns': -1.14,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2005-05-16',
#   'buy_index': 1396,
#   'sell_date': '2005-06-03',
#   'sell_index': 1410,
#   'buy_price': 61.72452163696289,
#   'sell_price': 67.59255981445312,
#   'returns': 9.51},
#  {'strategy': 4,
#   'buy_date': '2005-08-09',
#   'buy_index': 1457,
#   'sell_date': '2005-08-29',
#   'sell_index': 1470,
#   'buy_price': 67.52389526367188,
#   'sell_price': 66.3404312133789,
#   'returns': -1.75,
#   'trend_changed': True},
#  {'strategy': 2,
#   'buy_date': '2006-07-18',
#   'buy_index': 1688,
#   'sell_date': '2006-07-25',
#   'sell_index': 1693,
#   'buy_price': 92.47366333007812,
#   'sell_price': 89.52937316894531,
#   'returns': -3.18,
#   'trend_changed': True},
#  {'strategy': 4,
#   'buy_date': '2007-05-11',
#   'buy_index': 1888,
#   'sell_date': '2007-05-14',
#   'sell_index': 1889,
#   'buy_price': 104.8906478881836,
#   'sell_price': 104.55437469482422,
#   'returns': -0.32,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2007-09-07',
#   'buy_index': 1972,
#   'sell_date': '2007-09-12',
#   'sell_index': 1975,
#   'buy_price': 92.08964538574219,
#   'sell_price': 87.14099884033203,
#   'returns': -5.37,
#   'trend_changed': True},
#  {'strategy': 5,
#   'buy_date': '2007-12-05',
#   'buy_index': 2033,
#   'sell_date': '2007-12-19',
#   'sell_index': 2043,
#   'buy_price': 96.44329071044922,
#   'sell_price': 93.53340911865234,
#   'returns': -3.02,
#   'trend_changed': True},
#  {'strategy': 2,
#   'buy_date': '2007-12-20',
#   'buy_index': 2044,
#   'sell_date': '2008-01-11',
#   'sell_index': 2058,
#   'buy_price': 95.3895492553711,
#   'sell_price': 94.51946258544922,
#   'returns': -0.91},
#  {'strategy': 3,
#   'buy_date': '2008-02-28',
#   'buy_index': 2092,
#   'sell_date': '2008-03-10',
#   'sell_index': 2098,
#   'buy_price': 86.5051040649414,
#   'sell_price': 77.82364654541016,
#   'returns': -10.04,
#   'trend_changed': True},
#  {'strategy': 5,
#   'buy_date': '2008-03-31',
#   'buy_index': 2111,
#   'sell_date': '2008-04-11',
#   'sell_index': 2120,
#   'buy_price': 83.54682159423828,
#   'sell_price': 78.40370178222656,
#   'returns': -6.16,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2008-08-05',
#   'buy_index': 2198,
#   'sell_date': '2008-08-21',
#   'sell_index': 2209,
#   'buy_price': 87.25720977783203,
#   'sell_price': 82.09064483642578,
#   'returns': -5.92,
#   'trend_changed': True},
#  {'strategy': 2,
#   'buy_date': '2008-08-22',
#   'buy_index': 2210,
#   'sell_date': '2008-08-25',
#   'sell_index': 2211,
#   'buy_price': 81.64220428466797,
#   'sell_price': 81.88592529296875,
#   'returns': 0.3,
#   'trend_changed': True},
#  {'strategy': 2,
#   'buy_date': '2008-08-26',
#   'buy_index': 2212,
#   'sell_date': '2008-08-27',
#   'sell_index': 2213,
#   'buy_price': 83.6991195678711,
#   'sell_price': 83.1044692993164,
#   'returns': -0.71,
#   'trend_changed': True},
#  {'strategy': 2,
#   'buy_date': '2008-09-01',
#   'buy_index': 2216,
#   'sell_date': '2008-09-15',
#   'sell_index': 2225,
#   'buy_price': 84.62517547607422,
#   'sell_price': 78.74696350097656,
#   'returns': -6.95,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2008-12-18',
#   'buy_index': 2287,
#   'sell_date': '2008-12-29',
#   'sell_index': 2293,
#   'buy_price': 48.72211837768555,
#   'sell_price': 44.2281494140625,
#   'returns': -9.22,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2008-12-30',
#   'buy_index': 2294,
#   'sell_date': '2009-01-06',
#   'sell_index': 2298,
#   'buy_price': 45.992584228515625,
#   'sell_price': 47.318359375,
#   'returns': 2.88,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2009-01-14',
#   'buy_index': 2303,
#   'sell_date': '2009-01-19',
#   'sell_index': 2306,
#   'buy_price': 47.53282928466797,
#   'sell_price': 45.11524200439453,
#   'returns': -5.09,
#   'trend_changed': True},
#  {'strategy': 5,
#   'buy_date': '2009-03-18',
#   'buy_index': 2344,
#   'sell_date': '2009-04-09',
#   'sell_index': 2358,
#   'buy_price': 44.949520111083984,
#   'sell_price': 53.508541107177734,
#   'returns': 19.04},
#  {'strategy': 4,
#   'buy_date': '2010-06-30',
#   'buy_index': 2660,
#   'sell_date': '2010-07-05',
#   'sell_index': 2663,
#   'buy_price': 127.38886260986328,
#   'sell_price': 129.22764587402344,
#   'returns': 1.44,
#   'trend_changed': True},
#  {'strategy': 5,
#   'buy_date': '2010-07-12',
#   'buy_index': 2668,
#   'sell_date': '2010-07-30',
#   'sell_index': 2682,
#   'buy_price': 135.77099609375,
#   'sell_price': 136.59927368164062,
#   'returns': 0.61},
#  {'strategy': 4,
#   'buy_date': '2011-03-22',
#   'buy_index': 2843,
#   'sell_date': '2011-04-11',
#   'sell_index': 2857,
#   'buy_price': 144.5682373046875,
#   'sell_price': 153.08790588378906,
#   'returns': 5.89},
#  {'strategy': 3,
#   'buy_date': '2011-06-07',
#   'buy_index': 2895,
#   'sell_date': '2011-06-13',
#   'sell_index': 2899,
#   'buy_price': 146.63160705566406,
#   'sell_price': 144.91766357421875,
#   'returns': -1.17,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2011-07-12',
#   'buy_index': 2920,
#   'sell_date': '2011-07-14',
#   'sell_index': 2922,
#   'buy_price': 139.30841064453125,
#   'sell_price': 138.26675415039062,
#   'returns': -0.75,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2011-09-20',
#   'buy_index': 2967,
#   'sell_date': '2011-10-05',
#   'sell_index': 2978,
#   'buy_price': 117.92154693603516,
#   'sell_price': 110.19339752197266,
#   'returns': -6.55,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2011-10-10',
#   'buy_index': 2980,
#   'sell_date': '2011-11-01',
#   'sell_index': 2994,
#   'buy_price': 117.23274993896484,
#   'sell_price': 125.01129913330078,
#   'returns': 6.64},
#  {'strategy': 4,
#   'buy_date': '2012-04-17',
#   'buy_index': 3106,
#   'sell_date': '2012-04-20',
#   'sell_index': 3109,
#   'buy_price': 142.2100372314453,
#   'sell_price': 143.425537109375,
#   'returns': 0.85,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2012-08-23',
#   'buy_index': 3195,
#   'sell_date': '2012-09-12',
#   'sell_index': 3209,
#   'buy_price': 123.83454132080078,
#   'sell_price': 131.1500244140625,
#   'returns': 5.91},
#  {'strategy': 5,
#   'buy_date': '2012-11-08',
#   'buy_index': 3246,
#   'sell_date': '2012-12-03',
#   'sell_index': 3260,
#   'buy_price': 128.02944946289062,
#   'sell_price': 134.5775604248047,
#   'returns': 5.11},
#  {'strategy': 3,
#   'buy_date': '2013-06-20',
#   'buy_index': 3397,
#   'sell_date': '2013-07-10',
#   'sell_index': 3411,
#   'buy_price': 119.11161804199219,
#   'sell_price': 126.88111114501953,
#   'returns': 6.52},
#  {'strategy': 4,
#   'buy_date': '2014-04-22',
#   'buy_index': 3602,
#   'sell_date': '2014-04-25',
#   'sell_index': 3605,
#   'buy_price': 185.47891235351562,
#   'sell_price': 181.52842712402344,
#   'returns': -2.13,
#   'trend_changed': True},
#  {'strategy': 4,
#   'buy_date': '2014-12-10',
#   'buy_index': 3757,
#   'sell_date': '2014-12-15',
#   'sell_index': 3760,
#   'buy_price': 194.81080627441406,
#   'sell_price': 191.0708465576172,
#   'returns': -1.92,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2015-05-27',
#   'buy_index': 3869,
#   'sell_date': '2015-06-12',
#   'sell_index': 3881,
#   'buy_price': 196.5507049560547,
#   'sell_price': 191.2130584716797,
#   'returns': -2.72,
#   'trend_changed': True},
#  {'strategy': 5,
#   'buy_date': '2015-06-24',
#   'buy_index': 3889,
#   'sell_date': '2015-06-30',
#   'sell_index': 3893,
#   'buy_price': 201.1944580078125,
#   'sell_price': 194.54017639160156,
#   'returns': -3.31,
#   'trend_changed': True},
#  {'strategy': 1,
#   'buy_date': '2015-07-01',
#   'buy_index': 3894,
#   'sell_date': '2015-07-06',
#   'sell_index': 3897,
#   'buy_price': 196.69305419921875,
#   'sell_price': 195.7322540283203,
#   'returns': -0.49,
#   'trend_changed': True},
#  {'strategy': 1,
#   'buy_date': '2015-07-07',
#   'buy_index': 3898,
#   'sell_date': '2015-07-08',
#   'sell_index': 3899,
#   'buy_price': 197.06668090820312,
#   'sell_price': 196.69305419921875,
#   'returns': -0.19,
#   'trend_changed': True},
#  {'strategy': 5,
#   'buy_date': '2015-09-16',
#   'buy_index': 3949,
#   'sell_date': '2015-10-08',
#   'sell_index': 3962,
#   'buy_price': 209.16160583496094,
#   'sell_price': 212.4942169189453,
#   'returns': 1.59,
#   'trend_changed': True},
#  {'strategy': 5,
#   'buy_date': '2015-12-02',
#   'buy_index': 3997,
#   'sell_date': '2015-12-09',
#   'sell_index': 4002,
#   'buy_price': 208.15284729003906,
#   'sell_price': 203.66732788085938,
#   'returns': -2.15,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2015-12-10',
#   'buy_index': 4003,
#   'sell_date': '2015-12-11',
#   'sell_index': 4004,
#   'buy_price': 203.59527587890625,
#   'sell_price': 203.88348388671875,
#   'returns': 0.14,
#   'trend_changed': True},
#  {'strategy': 5,
#   'buy_date': '2016-02-01',
#   'buy_index': 4038,
#   'sell_date': '2016-02-09',
#   'sell_index': 4044,
#   'buy_price': 206.5717010498047,
#   'sell_price': 194.97328186035156,
#   'returns': -5.61,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2016-03-15',
#   'buy_index': 4068,
#   'sell_date': '2016-04-06',
#   'sell_index': 4082,
#   'buy_price': 193.8643341064453,
#   'sell_price': 202.9540252685547,
#   'returns': 4.69},
#  {'strategy': 3,
#   'buy_date': '2016-06-03',
#   'buy_index': 4121,
#   'sell_date': '2016-06-07',
#   'sell_index': 4123,
#   'buy_price': 196.62762451171875,
#   'sell_price': 196.28219604492188,
#   'returns': -0.18,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2016-06-08',
#   'buy_index': 4124,
#   'sell_date': '2016-06-15',
#   'sell_index': 4129,
#   'buy_price': 198.0092315673828,
#   'sell_price': 198.90000915527344,
#   'returns': 0.45,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2016-06-16',
#   'buy_index': 4130,
#   'sell_date': '2016-06-28',
#   'sell_index': 4138,
#   'buy_price': 199.93624877929688,
#   'sell_price': 197.2093505859375,
#   'returns': -1.36,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2016-10-20',
#   'buy_index': 4214,
#   'sell_date': '2016-10-27',
#   'sell_index': 4219,
#   'buy_price': 180.44204711914062,
#   'sell_price': 168.16734313964844,
#   'returns': -6.8,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2016-12-05',
#   'buy_index': 4244,
#   'sell_date': '2016-12-23',
#   'sell_index': 4258,
#   'buy_price': 166.32794189453125,
#   'sell_price': 167.0928497314453,
#   'returns': 0.46},
#  {'strategy': 2,
#   'buy_date': '2016-12-26',
#   'buy_index': 4259,
#   'sell_date': '2017-01-13',
#   'sell_index': 4273,
#   'buy_price': 166.1276092529297,
#   'sell_price': 176.52651977539062,
#   'returns': 6.26},
#  {'strategy': 5,
#   'buy_date': '2017-02-14',
#   'buy_index': 4294,
#   'sell_date': '2017-03-07',
#   'sell_index': 4308,
#   'buy_price': 174.395751953125,
#   'sell_price': 181.14547729492188,
#   'returns': 3.87},
#  {'strategy': 4,
#   'buy_date': '2018-03-26',
#   'buy_index': 4569,
#   'sell_date': '2018-03-27',
#   'sell_index': 4570,
#   'buy_price': 201.1346435546875,
#   'sell_price': 201.1713409423828,
#   'returns': 0.02,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2018-04-18',
#   'buy_index': 4584,
#   'sell_date': '2018-04-26',
#   'sell_index': 4590,
#   'buy_price': 214.8249969482422,
#   'sell_price': 206.53004455566406,
#   'returns': -3.86,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2018-07-10',
#   'buy_index': 4642,
#   'sell_date': '2018-07-25',
#   'sell_index': 4653,
#   'buy_price': 198.63877868652344,
#   'sell_price': 201.6484832763672,
#   'returns': 1.52,
#   'trend_changed': True},
#  {'strategy': 4,
#   'buy_date': '2018-11-22',
#   'buy_index': 4732,
#   'sell_date': '2018-11-27',
#   'sell_index': 4734,
#   'buy_price': 225.43228149414062,
#   'sell_price': 229.06593322753906,
#   'returns': 1.61,
#   'trend_changed': True},
#  {'strategy': 4,
#   'buy_date': '2019-06-26',
#   'buy_index': 4875,
#   'sell_date': '2019-06-28',
#   'sell_index': 4877,
#   'buy_price': 280.8621826171875,
#   'sell_price': 275.31658935546875,
#   'returns': -1.97,
#   'trend_changed': True},
#  {'strategy': 5,
#   'buy_date': '2019-12-20',
#   'buy_index': 4994,
#   'sell_date': '2020-01-10',
#   'sell_index': 5008,
#   'buy_price': 247.14694213867188,
#   'sell_price': 247.0978546142578,
#   'returns': -0.02},
#  {'strategy': 3,
#   'buy_date': '2020-05-12',
#   'buy_index': 5088,
#   'sell_date': '2020-05-18',
#   'sell_index': 5092,
#   'buy_price': 184.33465576171875,
#   'sell_price': 179.55506896972656,
#   'returns': -2.59,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2020-05-19',
#   'buy_index': 5093,
#   'sell_date': '2020-05-20',
#   'sell_index': 5094,
#   'buy_price': 181.7230987548828,
#   'sell_price': 182.26513671875,
#   'returns': 0.3,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2020-05-21',
#   'buy_index': 5095,
#   'sell_date': '2020-06-11',
#   'sell_index': 5109,
#   'buy_price': 186.3549041748047,
#   'sell_price': 209.8094024658203,
#   'returns': 12.59},
#  {'strategy': 3,
#   'buy_date': '2022-03-09',
#   'buy_index': 5545,
#   'sell_date': '2022-03-30',
#   'sell_index': 5559,
#   'buy_price': 579.2392578125,
#   'sell_price': 594.3756103515625,
#   'returns': 2.61},
#  {'strategy': 3,
#   'buy_date': '2022-08-02',
#   'buy_index': 5645,
#   'sell_date': '2022-08-22',
#   'sell_index': 5657,
#   'buy_price': 428.5444641113281,
#   'sell_price': 418.9680480957031,
#   'returns': -2.23,
#   'trend_changed': True},
#  {'strategy': 2,
#   'buy_date': '2022-08-23',
#   'buy_index': 5658,
#   'sell_date': '2022-08-25',
#   'sell_index': 5660,
#   'buy_price': 415.62628173828125,
#   'sell_price': 414.17987060546875,
#   'returns': -0.35,
#   'trend_changed': True},
#  {'strategy': 3,
#   'buy_date': '2022-11-14',
#   'buy_index': 5713,
#   'sell_date': '2022-12-02',
#   'sell_index': 5727,
#   'buy_price': 395.5756530761719,
#   'sell_price': 411.38671875,
#   'returns': 4.0},
#  {'strategy': 5,
#   'buy_date': '2023-01-16',
#   'buy_index': 5758,
#   'sell_date': '2023-02-06',
#   'sell_index': 5772,
#   'buy_price': 397.6206359863281,
#   'sell_price': 404.6499938964844,
#   'returns': 1.77},
#  {'strategy': 3,
#   'buy_date': '2023-04-27',
#   'buy_index': 5825,
#   'sell_date': '2023-05-18',
#   'sell_index': 5839,
#   'buy_price': 374.3999938964844,
#   'sell_price': 382.6000061035156,
#   'returns': 2.19},
#  {'strategy': 5,
#   'buy_date': '2023-07-06',
#   'buy_index': 5873,
#   'sell_date': '2023-07-26',
#   'sell_index': 5887,
#   'buy_price': 396.20001220703125,
#   'sell_price': 402.75,
#   'returns': 1.65}]

# %%
pd.DataFrame(TRADES)['returns'].mean(), pd.DataFrame(TRADES)['returns'].sum()
# Out:
# (1.7448051948051948, 134.35)

# %%
pd.DataFrame(TRADES).to_csv('trades_with_stoploss.csv', index=False)
